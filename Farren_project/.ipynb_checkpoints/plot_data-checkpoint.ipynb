# %%
# %matplotlib inline
import sys, imp
import ss_analysis
imp.reload(sys.modules['ss_analysis'])
from ss_analysis import run_plot_results
run_plot_results()
# Out:
# /projectnb/bioinfor/SEGRE/alizom/lib/python2.7/site-packages/matplotlib/font_manager.py:1282 UserWarning: findfont: Font family [u'STIXG'] not found. Falling back to Bitstream Vera Sans

# %%
from mpl_toolkits.mplot3d import Axes3D
