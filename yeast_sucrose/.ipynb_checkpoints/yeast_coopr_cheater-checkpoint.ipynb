# %%
import sys, imp
import matplotlib
# %matplotlib inline
#import dynamicAnalysis
import tools.ancillary.plot
imp.reload(sys.modules['dynamicAnalysis'])
imp.reload(sys.modules['tools.ancillary.plot'])
from dynamicAnalysis import plot_density, plot_results

#plot_results(results_filename_lowDensity = 'results/dynamic_coopr_density_effect_on_mu_low.py',results_filename_highDensity = 'results/dynamic_coopr_density_effect_on_mu_high.py' ,output_filename = 'results/coopr_density_effect_on_mu.pdf')

plot_density(results_filename_lowDensity = 'results/dynamic_coopr_density_effect_on_mu_low.py',results_filename_highDensity = 'results/dynamic_coopr_density_effect_on_mu_high.py' ,output_filename = 'results/coopr_density_effect_on_mu.pdf')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-cf403a68c0b6> in <module>()
#       4 get_ipython().magic(u'matplotlib inline')
#       5 #import dynamicAnalysis
# ----> 6 import tools.ancillary.plot
#       7 imp.reload(sys.modules['dynamicAnalysis'])
#       8 imp.reload(sys.modules['tools.ancillary.plot'])
#
# ImportError: No module named tools.ancillary.plot

# %%
# %matplotlib inline
import sys, imp
#import simulate_games  # Use in the first ruh
#import tools.ancillary.plot_heatmap  # Use in the first run
#import tools.ancillary.plot  # Use in the first run
imp.reload(sys.modules['simulate_games'])
imp.reload(sys.modules['tools.ancillary.plot_heatmap'])
imp.reload(sys.modules['tools.ancillary.plot'])
from simulate_games import run_plot_results
from tools.ancillary.plot_heatmap import plot_heatmap
from tools.ancillary.plot import plot
run_plot_results()
# Out:
# Maximum value of the cost other than 10 and 15 =  0.493456914995
#
# min results/data = 0/0.0   ,  max results/data = 0.493456914995/0.6
# The figure was saved into results/cost_results_his_fixedo2.pdf
#
#
# --- Nash equilibria ---
# [[('player_1', 'Defect'), ('player_2', 'Cooperate')], [('player_1', 'Cooperate'), ('player_2', 'Defect')]]
# [[('player_1', 'Cooperate'), ('player_2', 'Cooperate')]]
# [[('player_1', 'Defect'), ('player_2', 'Defect')]]
# The figure was saved into results/ss_game_results_his_fixedo2.pdf

# %%
S = 1.46
print 0.12*S/(120 + S) + 0.12*S/(7.95 + S)
# Out:
# 0.0200609411564

# %%
type(5.0)
# Out:
# float
